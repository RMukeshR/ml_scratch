# %%
# import os

# os.mkdir("/home/mukesh/Infernape/ml_scratch/data")

# %%
# import shutil


# shutil.move("/home/mukesh/Downloads/archive (2)/insurance.csv" , "/home/mukesh/Infernape/ml_scratch/data/insurance.csv")

# %%
import pandas as pd

df = pd.read_csv("/home/mukesh/Infernape/ml_scratch/data/insurance.csv")

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
print(df[df.duplicated(keep=False)])
# Out:
#      age   sex    bmi  children smoker     region    charges
# 195   19  male  30.59         0     no  northwest  1639.5631
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (1337, 7)

# %%
df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1337 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.corr(numeric_only=True)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109344  0.041536  0.298308
# bmi       0.109344  1.000000  0.012755  0.198401
# children  0.041536  0.012755  1.000000  0.067389
# charges   0.298308  0.198401  0.067389  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('darkgrid')
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
df['sex'].value_counts().plot(kind='pie', colors=['gold', 'violet'], shadow=True, autopct='%.2f')
plt.title('Distribution Of Sex', fontsize=15)

plt.subplot(1,2,2)
sns.countplot(x=df['sex'], palette='pink')
plt.title('Distribution Of Sex (CountPlot)', fontsize=15)
plt.show()
# Out:
# /tmp/ipykernel_17919/1162186700.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['sex'], palette='pink')

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
df['smoker'].value_counts().plot(kind='pie', colors=['lightgreen', 'violet'], shadow=True, autopct='%.2f')
plt.title('Distribution Of Smoker', fontsize=15)

plt.subplot(1,2,2)
sns.countplot(x=df['smoker'], palette='crest')
plt.title('Distribution Of Smoker (CountPlot)', fontsize=15)
plt.show()
# Out:
# /tmp/ipykernel_17919/1161967912.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['smoker'], palette='crest')

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
df['region'].value_counts().plot(kind='pie', colors=['lightgreen', 'violet', 'yellow', 'gold'], shadow=True, autopct='%.2f')
plt.title('Distribution Of Region', fontsize=15)

plt.subplot(1,2,2)
sns.countplot(x=df['region'], palette='Purples')
plt.title('Distribution Of Region (CountPlot)', fontsize=15)
plt.show()
# Out:
# /tmp/ipykernel_17919/1217983204.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['region'], palette='Purples')

# %%
plt.figure(figsize=(13,6))
sns.countplot(x=df['smoker'],hue=df['sex'], palette='pink')
plt.title('Distribution Of Region (CountPlot)', fontsize=15)
plt.xlabel('Smoker', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(13,6))
sns.countplot(x=df['children'], palette='YlOrBr')
plt.title('Distribution Of Children', fontsize=15)
plt.xlabel('Children', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.show()
# Out:
# /tmp/ipykernel_17919/483681639.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['children'], palette='YlOrBr')

# %%
plt.figure(figsize=(13,6))
sns.scatterplot(x=df['age'], y=df['charges'])
plt.title('Age Vs. Charges', fontsize=15)
plt.xlabel('Age', fontsize=13)
plt.ylabel('Charges', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(13,6))
sns.scatterplot(x=df['bmi'], y=df['charges'],hue=df['smoker'], s=100, alpha=0.8, palette='cividis')
plt.title('BMI Vs. Charges With Smoker', fontsize=15)
plt.xlabel('BMI', fontsize=13)
plt.ylabel('Charges', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(13,6))
sns.heatmap(df.corr(numeric_only=True), cmap='Reds', annot=True, linewidths=2)
plt.title('Correlation Metrics Of Numerical Features', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(14, 10))
for i, cols  in enumerate(['age', 'bmi', 'children', 'charges']):
    plt.subplot(2, 2, i+1)
    sns.histplot(x=cols, data=df, kde=True, color='skyblue')
    plt.title(f'Distribution Of {cols}', fontsize=14)
    plt.tight_layout(pad=4.0)
plt.show()

# %%
plt.figure(figsize=(14, 10))
for i, cols  in enumerate(['age', 'bmi', 'children', 'charges']):
    plt.subplot(2, 2, i+1)
    sns.violinplot(x=cols, data=df,color='lightgreen')
    plt.title(f'ViolinPlot Of {cols}', fontsize=14)
    plt.tight_layout(pad=4.0)
plt.show()

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 4.2 MB/s eta 0:00:0000:0100:02
# ...

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
le  = LabelEncoder()
for i in ['sex', 'smoker', 'region']:
    df[i] = le.fit_transform(df[i])

# %%
X = df.drop('charges', axis=1)
y = df['charges']
X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=0.2)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1069, 6)
# (1069,)
# (268, 6)
# (268,)

# %%
scaler = StandardScaler()
scaler.fit(X_train, X_test)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.26248346, -1.00468826,  0.03605754,  0.75131418, -0.49883041,
#         -0.45606483],
#        [-1.42827115, -1.00468826, -0.99492834, -0.06823159, -0.49883041,
#         -0.45606483],
#        [-1.28737493,  0.99533362, -0.79624442,  2.39040573,  2.00468934,
#          1.34295105],
#        ...,
#        [ 1.4601013 , -1.00468826,  0.00516971, -0.88777737, -0.49883041,
#          1.34295105],
#        [-0.72379006,  0.99533362, -0.12255567,  0.75131418, -0.49883041,
#         -0.45606483],
#        [-0.16020519, -1.00468826,  0.7231032 ,  0.75131418,  2.00468934,
#          1.34295105]], shape=(1069, 6))

# %%
regression_models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(),
    'Lasso Regression': Lasso(),
    'Random Forest Regressor': RandomForestRegressor(),
    'Adaboost Regerssor': AdaBoostRegressor(),
    'Bagging Regressor': BaggingRegressor(),
    'Gradient Boosting Regressor': GradientBoostingRegressor(),
    'KNeighbors Regressor': KNeighborsRegressor(),
    'XGBoost Regressor': XGBRegressor()
}

# %%
for model_names, model in regression_models.items():
    model.fit(X_train_scaled, y_train)
    predictions = model.predict(X_test_scaled)
    r2 = r2_score(y_test, predictions)*100
    mae = mean_absolute_error(y_test, predictions)
    mse = mean_squared_error(y_test, predictions)
    print(f'\n✔ Performance Of - {model_names}')
    print(f'R2 Score: {r2}')
    print(f'MAE: {mae}')
    print(f'MSE: {mse}')
    print('======================================================')
    
    plt.figure(figsize=(7, 4))
    sns.kdeplot(y_test.values, color='navy', label='Actual Values')
    sns.kdeplot(predictions, color='hotpink', label='Predicted Values')
    plt.title(f'{model_names}- Actual VS Predicted', fontsize=14)
    plt.legend()
    plt.show()
# Out:
# ✔ Performance Of - Linear Regression
# R2 Score: 77.1948492146154
# MAE: 4478.419338896215
# MSE: 35432844.698831655
# ...
# ✔ Performance Of - Ridge Regression
# R2 Score: 77.18916601301635
# MAE: 4480.399495107525
# MSE: 35441674.8092548
# ...
# ✔ Performance Of - Lasso Regression
# R2 Score: 77.1959754858387
# MAE: 4478.223526578167
# MSE: 35431094.78743139
# ...
# ✔ Performance Of - Random Forest Regressor
# R2 Score: 88.16703315495663
# MAE: 2529.250332583538
# MSE: 18385130.64406273
# ...
# ✔ Performance Of - Adaboost Regerssor
# R2 Score: 84.41942501021842
# MAE: 4150.333517508977
# MSE: 24207868.61384136
# ...
# ✔ Performance Of - Bagging Regressor
# R2 Score: 86.34020330560843
# MAE: 2741.022622802239
# MSE: 21223514.785974625
# ...
# ✔ Performance Of - Gradient Boosting Regressor
# R2 Score: 89.35334786466288
# MAE: 2495.557082549454
# MSE: 16541928.410122665
# ...
# ✔ Performance Of - KNeighbors Regressor
# R2 Score: 85.25320184643984
# MAE: 3129.4534897380595
# MSE: 22912411.923844382
# ...
